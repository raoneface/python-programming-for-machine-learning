# %% [markdown]
# ## what is abstraction in python
# Abstraction is one of the fundamental principles of object-oriented programming (OOP) that focuses on hiding the internal implementation details of an object and exposing only the necessary features to the user. In Python, abstraction can be achieved using abstract classes and interfaces.
# ### Abstract Classes
#
# An abstract class is a class that cannot
# be instantiated and is meant to be subclassed. It can contain abstract methods, which are methods that are declared but not implemented in the abstract class. Subclasses of the abstract class must provide an implementation for the abstract methods.

# %%
import abc
class pwskills:

    @abc.abstractmethod
    def student_details(self):
        pass

    @abc.abstractmethod
    def student_assignment(self):
        pass 
    
    @abc.abstractmethod
    def student_marks(self):
        pass

# %%
class student_details(pwskills):

    def student_marks(self):
        return "this is a method fro taking student details"
    
    def student_assignment(self):
        return "this is a method for assing details for a particular student"

# %%
class data_science_maters(pwskills):

    def student_details(self):
        return "this will return a student details for data science masters"
    
    def student_assignment(self):
        return "this is a meth for assing details for a particular student"

# %%
dsm = data_science_maters()
dsm.student_details()
# Out:
# 'this will return a student details for data science masters'

# %%
sd = student_details()
sd.student_marks()
# Out:
# 'this is a method fro taking student details'
